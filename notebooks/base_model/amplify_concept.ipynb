# %% [markdown]
# # Steerling-8B: Concept Amplify
#
# **Concept Amplify** amplifies a target concept during generation, with no weight updates. Steerling does this at inference time by injecting the concept direction into its hidden state.
#
# The public Amplify recipe is `injection`. It adds the concept direction to the residual stream (the running hidden state) at the deeper layers, pushing generation toward the concept.
#
# Amplify uses a **hard_cutoff** schedule. Full strength applies for the first `cutoff_tokens` generated tokens, then drops to zero. This plants the concept early and lets the rest generate unsteered, which keeps the text fluent.
#
# **Requirements:** an interpretable Steerling checkpoint and a GPU with >= 18 GB VRAM.

# %% [markdown]
# ## 1. Load the model
#
# Amplify needs the **interpretable** model, which exposes the concept heads the injection is built from. We load via HuggingFace `AutoModel` and wrap it in `SteerlingGenerator`.

# %%
import torch
from transformers import AutoModel, AutoTokenizer
from steerling import SteerlingGenerator, GenerationConfig, SteeringConfig

model = AutoModel.from_pretrained("guidelabs/steerling-8b", trust_remote_code=True, dtype=torch.bfloat16)
tokenizer = AutoTokenizer.from_pretrained("guidelabs/steerling-8b", trust_remote_code=True)
generator = SteerlingGenerator.from_model(model, tokenizer, device="cuda")

# %% [markdown]
# ## 2. Choose a concept and a neutral prompt
#
# Set the target concept and a **neutral** prompt, one that does not mention the concept. Amplify should weave the concept into the continuation that would otherwise be generic.
#
# Set `CONCEPT_ID`, `CONCEPT_LABEL`, and `CONCEPT_DESCRIPTION` to a concept from your concept table.

# %%
# --- target concept (replace with one from your concept table) --- See search_concepts.ipynb
CONCEPT_ID = 20353
CONCEPT_LABEL = "Books and publishing"

# --- neutral prompt (no mention of the concept) ---
PROMPT = "Today lets talk about"

# --- generation budget ---
MAX_NEW_TOKENS = 128
STEPS = 128

# --- Amplify strength ---
# mai_lm_target reads in logit units (positive amplifies). 7 is the preset default for Base model
# steering strength: reduce if you see repetition, increase if you do not see the concept
ALPHA = 7.0
# hard_cutoff: tokens generated at full strength before injection stops.
CUTOFF_TOKENS = 32
# inject_layer=None resolves to n_layers // 2 inside the generator.
INJECT_LAYER = 8

print(PROMPT)

# %% [markdown]
# ## 3. Reference generation
#
# First generate with no intervention. This is the baseline the steered run is compared against. Reference sampling uses `temperature=1.2`, `top_p=0.8`, `repetition_penalty=1.1`.

# %%
ref_config = GenerationConfig(
    max_new_tokens=MAX_NEW_TOKENS,
    steps=STEPS,
    temperature=1.2,
    top_p=0.8,
    repetition_penalty=1.1,
    seed=0,
)

reference = generator.generate_full(PROMPT, ref_config)
print(reference.text)

# %% [markdown]
# ## 4. Steer toward the concept (`injection`)
#
# `SteeringConfig.injection` builds the steering config: positive injection of the concept direction on the hard_cutoff schedule. We pass it to `generate_steered`. Steered sampling uses `temperature=0.9`, `top_p=0.7`, `repetition_penalty=1.5`.

# %%
steered_config = GenerationConfig(
    max_new_tokens=MAX_NEW_TOKENS,
    steps=STEPS,
    temperature=0.9,
    top_p=0.7,
    repetition_penalty=1.5,
    seed=0,
)

steer = SteeringConfig.injection(
    concept_ids=CONCEPT_ID,
    mai_lm_target=ALPHA,
    inject_layer=INJECT_LAYER,
    cutoff_tokens=CUTOFF_TOKENS,
)

steered = generator.generate_steered(PROMPT, steered_config, steer)
print(steered.text)
